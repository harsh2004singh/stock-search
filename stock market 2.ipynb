# %%
import nselib

from nselib import capital_market
# Out:
# C:\Users\Harsh\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
nselib.trading_holiday_calendar()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File ~\anaconda3\Lib\socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# ...

# %%
capital_market.bhav_copy_with_delivery('27-05-2025')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File ~\anaconda3\Lib\socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# ...

# %%
capital_market.block_deals_data(period='6M')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File ~\anaconda3\Lib\socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# ...

# %%
capital_market.bulk_deal_data(period='3M')
# Out:
#    Date Symbol SecurityName ClientName Buy/Sell QuantityTraded  \
# 0   NaN    NaN          NaN        NaN      NaN            NaN
# 1   NaN    NaN          NaN        NaN      NaN            NaN
# 2   NaN    NaN          NaN        NaN      NaN            NaN
# 3   NaN    NaN          NaN        NaN      NaN            NaN
# 4   NaN    NaN          NaN        NaN      NaN            NaN
# 5   NaN    NaN          NaN        NaN      NaN            NaN
# 6   NaN    NaN          NaN        NaN      NaN            NaN
# 7   NaN    NaN          NaN        NaN      NaN            NaN
# 8   NaN    NaN          NaN        NaN      NaN            NaN
# 9   NaN    NaN          NaN        NaN      NaN            NaN
# 10  NaN    NaN          NaN        NaN      NaN            NaN
#
#    TradePrice/Wght.Avg.Price Remarks  \
# 0                        NaN     NaN
# 1                        NaN     NaN
# 2                        NaN     NaN
# 3                        NaN     NaN
# ...

# %%
capital_market.deliverable_position_data('TATAMOTORS',period='6M')
# Out:
#    Symbol Series Date TradedQty DeliverableQty %DlyQttoTradedQty  \
# 0     NaN    NaN  NaN       NaN            NaN               NaN
# 1     NaN    NaN  NaN       NaN            NaN               NaN
# 2     NaN    NaN  NaN       NaN            NaN               NaN
# 3     NaN    NaN  NaN       NaN            NaN               NaN
# 4     NaN    NaN  NaN       NaN            NaN               NaN
# 5     NaN    NaN  NaN       NaN            NaN               NaN
# 6     NaN    NaN  NaN       NaN            NaN               NaN
# 7     NaN    NaN  NaN       NaN            NaN               NaN
# 8     NaN    NaN  NaN       NaN            NaN               NaN
# 9     NaN    NaN  NaN       NaN            NaN               NaN
# 10    NaN    NaN  NaN       NaN            NaN               NaN
#
#                                        <!DOCTYPEhtml>
# 0                                    <html lang="en">
# 1                                              <head>
# ...

# %%
capital_market.price_volume_and_deliverable_position_data('CESC',period='6M')
# Out:
#    Symbol Series Date PrevClose OpenPrice HighPrice LowPrice LastPrice  \
# 0     NaN    NaN  NaN       NaN       NaN       NaN      NaN       NaN
# 1     NaN    NaN  NaN       NaN       NaN       NaN      NaN       NaN
# 2     NaN    NaN  NaN       NaN       NaN       NaN      NaN       NaN
# 3     NaN    NaN  NaN       NaN       NaN       NaN      NaN       NaN
# 4     NaN    NaN  NaN       NaN       NaN       NaN      NaN       NaN
# 5     NaN    NaN  NaN       NaN       NaN       NaN      NaN       NaN
# 6     NaN    NaN  NaN       NaN       NaN       NaN      NaN       NaN
# 7     NaN    NaN  NaN       NaN       NaN       NaN      NaN       NaN
# 8     NaN    NaN  NaN       NaN       NaN       NaN      NaN       NaN
# 9     NaN    NaN  NaN       NaN       NaN       NaN      NaN       NaN
# 10    NaN    NaN  NaN       NaN       NaN       NaN      NaN       NaN
#
#    ClosePrice AveragePrice TotalTradedQuantity TurnoverInRs No.ofTrades  \
# ...

# %%
capital_market.price_volume_data('CDSL',period='1M')
# Out:
#    Symbol Series         Date PrevClose OpenPrice HighPrice  LowPrice  \
# 0     NaN     EQ  07-Feb-2024  1,850.35  1,866.90  1,998.85  1,848.00
# 1     NaN     EQ  08-Feb-2024  1,957.95  1,978.00  2,044.00  1,919.00
# 2     NaN     EQ  09-Feb-2024  2,000.30  2,012.00  2,067.00  1,916.10
# 3     NaN     EQ  12-Feb-2024  1,946.95  1,958.00  1,958.95  1,825.00
# 4     NaN     EQ  13-Feb-2024  1,849.85  1,849.85  1,900.00  1,807.35
# 5     NaN     EQ  14-Feb-2024  1,885.50  1,848.00  1,907.00  1,837.70
# 6     NaN     EQ  15-Feb-2024  1,898.70  1,912.65  1,916.45  1,871.65
# 7     NaN     EQ  16-Feb-2024  1,878.40  1,883.00  1,906.00  1,870.10
# 8     NaN     EQ  19-Feb-2024  1,876.15  1,868.40  1,883.55  1,832.00
# 9     NaN     EQ  20-Feb-2024  1,841.50  1,843.95  1,866.50  1,835.00
# 10    NaN     EQ  21-Feb-2024  1,841.30  1,842.00  1,856.95  1,786.35
# 11    NaN     EQ  22-Feb-2024  1,799.60  1,807.00  1,828.90  1,793.00
# ...

# %%
capital_market.equity_list()
# Out:
#           SYMBOL                           NAME OF COMPANY  SERIES  \
# 0      20MICRONS                        20 Microns Limited      EQ
# 1     21STCENMGM  21st Century Management Services Limited      BE
# 2         360ONE                       360 ONE WAM LIMITED      EQ
# 3      3IINFOLTD                       3i Infotech Limited      EQ
# 4        3MINDIA                          3M India Limited      EQ
# ...          ...                                       ...     ...
# 1955        ZOTA                  Zota Health Care LImited      EQ
# 1956       ZUARI              Zuari Agro Chemicals Limited      EQ
# 1957    ZUARIIND                  ZUARI INDUSTRIES LIMITED      EQ
# 1958   ZYDUSLIFE                Zydus Lifesciences Limited      EQ
# 1959   ZYDUSWELL                    Zydus Wellness Limited      EQ
#
#       DATE OF LISTING   FACE VALUE
# 0         06-OCT-2008            5
# 1         03-MAY-1995           10
# 2         19-SEP-2019            1
# ...

# %%
capital_market.fno_equity_list()
# Out:
#                              Company_Name      Symbol       MAR-24
# 0    NIFTY MID SELECT                      MIDCPNIFTY  75
# 1    NIFTY FINANCIAL SERVICES              FINNIFTY    40
# 2    NIFTY BANK                            BANKNIFTY   15
# 3    NIFTY 50                              NIFTY       50
# 4    APOLLO HOSPITALS ENTER. L             APOLLOHOSP          125
# ..                                    ...         ...          ...
# 181  GAIL (INDIA) LTD                      GAIL               4575
# 182  NMDC LTD.                             NMDC               4500
# 183  JSW STEEL LIMITED                     JSWSTEEL            675
# 184  OBEROI REALTY LIMITED                 OBEROIRLTY          700
# 185  PVR INOX LIMITED                      PVRINOX             407
#
# [186 rows x 3 columns]

# %%
capital_market.index_data('NIFTY ',period='1M')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 capital_market.index_data('NIFTY ',period='1M')
#
# NameError: name 'capital_market' is not defined

# %%
capital_market.india_vix_data(period='1M')
# Out:
#       TIMESTAMP INDEX_NAME  OPEN_INDEX_VAL  CLOSE_INDEX_VAL  HIGH_INDEX_VAL  \
# 0   07-FEB-2024  INDIA VIX         15.7850          15.5050         16.0175
# 1   08-FEB-2024  INDIA VIX         15.5050          15.8275         16.0275
# 2   09-FEB-2024  INDIA VIX         15.8275          15.4475         16.3325
# 3   12-FEB-2024  INDIA VIX         15.4475          16.0625         16.5350
# 4   13-FEB-2024  INDIA VIX         16.0625          15.8075         16.5700
# 5   14-FEB-2024  INDIA VIX         15.8075          15.4350         16.1975
# 6   15-FEB-2024  INDIA VIX         15.4350          15.2250         15.6625
# 7   16-FEB-2024  INDIA VIX         15.2250          15.2225         15.5525
# 8   19-FEB-2024  INDIA VIX         15.2225          16.0175         16.1175
# 9   20-FEB-2024  INDIA VIX         16.0175          16.0725         16.3600
# 10  21-FEB-2024  INDIA VIX         16.0725          15.9275         16.3100
# ...

# %%
capital_market.market_watch_all_indices()
# Out:
#                      key                                      index  \
# 0   BROAD MARKET INDICES                                   NIFTY 50
# 1   BROAD MARKET INDICES                              NIFTY NEXT 50
# 2   BROAD MARKET INDICES                                  NIFTY 100
# 3   BROAD MARKET INDICES                                  NIFTY 200
# 4   BROAD MARKET INDICES                                  NIFTY 500
# ..                   ...                                        ...
# 68  FIXED INCOME INDICES  NIFTY 10 YR BENCHMARK G-SEC (CLEAN PRICE)
# 69  FIXED INCOME INDICES                   NIFTY 4-8 YR G-SEC INDEX
# 70  FIXED INCOME INDICES                 NIFTY 11-15 YR G-SEC INDEX
# 71  FIXED INCOME INDICES          NIFTY 15 YR AND ABOVE G-SEC INDEX
# 72  FIXED INCOME INDICES                NIFTY COMPOSITE G-SEC INDEX
#
#           indexSymbol      last  variation  percentChange      open      high  \
# ...

# %%
capital_market.nifty50_equity_list()
# Out:
#                                   Company Name  \
# 0                       Adani Enterprises Ltd.
# 1   Adani Ports and Special Economic Zone Ltd.
# 2             Apollo Hospitals Enterprise Ltd.
# 3                            Asian Paints Ltd.
# 4                               Axis Bank Ltd.
# 5                              Bajaj Auto Ltd.
# 6                           Bajaj Finance Ltd.
# 7                           Bajaj Finserv Ltd.
# 8                      Bharat Electronics Ltd.
# 9                           Bharti Airtel Ltd.
# 10                                  Cipla Ltd.
# 11                             Coal India Ltd.
# 12               Dr. Reddy's Laboratories Ltd.
# 13                          Eicher Motors Ltd.
# 14                                Eternal Ltd.
# 15                      Grasim Industries Ltd.
# 16                       HCL Technologies Ltd.
# 17                              HDFC Bank Ltd.
# 18            HDFC Life Insurance Company Ltd.
# ...

# %%
capital_market.short_selling_data(period='1M')
# Out:
#    Date Symbol SecurityName Quantity  \
# 0   NaN    NaN          NaN      NaN
# 1   NaN    NaN          NaN      NaN
# 2   NaN    NaN          NaN      NaN
# 3   NaN    NaN          NaN      NaN
# 4   NaN    NaN          NaN      NaN
# 5   NaN    NaN          NaN      NaN
# 6   NaN    NaN          NaN      NaN
# 7   NaN    NaN          NaN      NaN
# 8   NaN    NaN          NaN      NaN
# 9   NaN    NaN          NaN      NaN
# 10  NaN    NaN          NaN      NaN
#
#                                        <!DOCTYPEhtml>
# 0                                    <html lang="en">
# 1                                              <head>
# 2                              <meta charset="UTF-8">
# 3                   <title>Resource not found</title>
# 4                                             </head>
# 5           <body style="background-color: #e8e8e8;">
# 6     <div style="font-size: 32px; padding: 50px 2...
# 7                                  Resource not found
# ...

# %%
import bsedata as bse

# %%
from bsedata.bse import BSE

bse = BSE(update_codes = True)

# %%
stock_data = bse.getQuote('500325')   #Reliance Industries Ltd. stock code is '500325'
print(stock_data)
# Out:
# {'companyName': 'Reliance Industries Ltd', 'currentValue': '1421.75', 'change': '-12.40', 'pChange': '-0.86', 'updatedOn': '27 May 25 | 04:00 PM', 'securityID': 'RELIANCE', 'scripCode': '500325', 'group': 'A  / BSE SENSEX', 'faceValue': '10.00', 'industry': 'Oil, Gas & Consumable Fuels', 'previousClose': '1434.15', 'previousOpen': '1429.15', 'dayHigh': '1437.30', 'dayLow': '1414.00', '52weekHigh': '1608.95', '52weekLow': '1115.55', 'weightedAvgPrice': '1421.71', 'totalTradedValue': '185.25 Cr.', 'totalTradedQuantity': '13.03 Lakh', '2WeekAvgQuantity': '5.28 Lakh', 'marketCapFull': '19,23,979.30 Cr.', 'marketCapFreeFloat': '9,60,581.30 Cr.', 'buy': {'1': {'quantity': '-', 'price': '0.00'}, '2': {'quantity': '-', 'price': '0.00'}, '3': {'quantity': '-', 'price': '0.00'}, '4': {'quantity': '-', 'price': '0.00'}, '5': {'quantity': '-', 'price': '0.00'}}, 'sell': {'1': {'price': '0.00', 'quantity': '-'}, '2': {'price': '0.00', 'quantity': '-'}, '3': {'price': '0.00', 'quantity': '-'}, '4'
# ...

# %%
bse.topGainers()  # Retrieves data for top gainers
# Out:
# [{'securityID': 'RALLIS',
#   'scripCode': '500355',
#   'LTP': '287.95',
#   'change': '33.50',
#   'pChange': '13.17'},
#  {'securityID': 'TATACHEM',
#   'scripCode': '500770',
#   'LTP': '1,314.90',
#   'change': '136.35',
#   'pChange': '11.57'},
#  {'securityID': 'FORCEMOT',
#   'scripCode': '500033',
#   'LTP': '6,484.75',
#   'change': '589.50',
#   'pChange': '10.00'},
#  {'securityID': 'IIFL',
#   'scripCode': '532636',
#   'LTP': '420.40',
#   'change': '37.60',
#   'pChange': '9.82'},
#  {'securityID': 'TTML',
#   'scripCode': '532371',
#   'LTP': '89.89',
#   'change': '6.54',
#   'pChange': '7.85'}]

# %%
bse.topLosers()   # Retrieves data for top losers
# Out:
# [{'securityID': 'JPASSOCIAT',
#   'scripCode': '532532',
#   'LTP': '17.85',
#   'change': '-0.85',
#   'pChange': '-4.55'},
#  {'securityID': 'HBLPOWER',
#   'scripCode': '517271',
#   'LTP': '466.90',
#   'change': '-20.95',
#   'pChange': '-4.29'},
#  {'securityID': 'PRICOLLTD',
#   'scripCode': '540293',
#   'LTP': '357.65',
#   'change': '-14.55',
#   'pChange': '-3.91'},
#  {'securityID': 'NLCINDIA',
#   'scripCode': '513683',
#   'LTP': '218.20',
#   'change': '-8.50',
#   'pChange': '-3.75'},
#  {'securityID': 'M&M',
#   'scripCode': '500520',
#   'LTP': '1,896.25',
#   'change': '-72.45',
#   'pChange': '-3.68'}]

# %%
bse.getIndices('market_cap')
# Out:
# ### Invalid category ###
# Use one of the categories mentioned below:
#
# market_cap/broad
# sector_and_industry
# thematics
# strategy
# sustainability
# volatility
# composite
# government
# corporate
# money_market

# %%
bse.getScripCodes()
# Out:
# {'533022': '20 Microns Ltd.',
#  '532628': '3i Infotech Ltd.',
#  '523395': '3m India Ltd.',
#  '590116': '7seas Technologies Ltd-$',
#  '512161': '8k Miles Software Services Ltd.',
#  '538351': 'A.f. Enterprises Ltd',
#  '539300': 'A.k. Spintex Ltd',
#  '530499': 'A.k.capital Services Ltd.',
#  '533292': 'A2z Infra Engineering Limited',
#  '531611': 'Aadhaar Ventures India Ltd.',
#  '530027': 'Aadi Industries Ltd.',
#  '531866': 'Aagam Capital Ltd.',
#  '539096': 'Aananda Lakshmi Spinning Mills Ltd',
#  '538812': 'Aanchal Ispat Ltd',
#  '524412': 'Aarey Drugs & Pharmaceuticals Ltd.',
#  '524348': 'Aarti Drugs Ltd.',
#  '524208': 'Aarti Industries Ltd.',
#  '514274': 'Aarvee Denims & Exports Ltd.',
#  '531731': 'Aarya Global Shares And Securities Ltd.',
#  '519319': 'Aashee Infotech Ltd.',
#  '512038': 'Aaswa Trading & Exports Ltd.',
#  '523204': 'Aban Offshore Ltd.',
#  '512165': 'Abans Enterprises Ltd',
#  '500002': 'Abb India Limited',
#  '500488': 'Abbott India Ltd.',
# ...

# %%
from bsedata.bse import BSE

def get_real_time_stock_price(stock_code):
    bse = BSE(update_codes=True)  # Initialize BSE object with update_codes = True for real-time data
    stock_data = bse.getQuote(stock_code)
    if stock_data:
        return stock_data['currentValue']
    else:
        return None

def main():
    stock_code = '500209'  # Example: infosys stock code
    real_time_price = get_real_time_stock_price(stock_code)
    if real_time_price:
        print(f"Real-time price for stock with code {stock_code}: {real_time_price}")
    else:
        print(f"Unable to fetch real-time price for stock with code {stock_code}")

#if __name__ == "__main__":
    main()

# %%
bse.getIndices("sector_and_industry")
# Out:
# {'updatedOn': '20 Mar 2024',
#  'indices': [{'currentValue': '6,353.73',
#    'change': '-41.80',
#    'pChange': '-0.65',
#    'scripFlag': '88',
#    'name': 'S&P BSE Commodities'},
#   {'currentValue': '8,224.46',
#    'change': '+24.88',
#    'pChange': '0.30',
#    'scripFlag': '89',
#    'name': 'S&P BSE Consumer Discretionary'},
#   {'currentValue': '11,579.31',
#    'change': '+124.45',
#    'pChange': '1.09',
#    'scripFlag': '90',
#    'name': 'S&P BSE Energy'},
#   {'currentValue': '18,983.96',
#    'change': '+89.39',
#    'pChange': '0.47',
#    'scripFlag': '83',
#    'name': 'S&P BSE Fast Moving Consumer Goods'},
#   {'currentValue': '10,051.10',
#    'change': '-36.79',
#    'pChange': '-0.36',
#    'scripFlag': '91',
#    'name': 'S&P BSE Financial Services'},
#   {'currentValue': '33,770.41',
#    'change': '+73.57',
#    'pChange': '0.22',
#    'scripFlag': '84',
#    'name': 'S&P BSE Healthcare'},
#   {'currentValue': '11,781.73',
#    'change': '+26.66',
# ...

# %%
from bsedata.bse import BSE

def get_real_time_stock_price(stock_code):
    bse = BSE(update_codes=True)  # Initialize BSE object with update_codes = True for real-time data
    stock_data = bse.getQuote(stock_code)
    if stock_data:
        return stock_data['currentValue']
    else:
        return None

def main():
    stock_code = '500209'  # Example: infosys stock code
    real_time_price = get_real_time_stock_price(stock_code)
    if real_time_price:
        print(f"Real-time price for stock with code {stock_code}: {real_time_price}")
    else:
        print(f"Unable to fetch real-time price for stock with code {stock_code}")
